# %% [markdown]
# # An intern conducted by: Lets Grow More
# #Name: Sundar Akkammagari
# #Date: From: 01/July/2022 To: 30/July/2022
# #Task-3: Image_to_sketch

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread("Sundar-Pichai.jpg")
image
# Out:
# array([[[174, 155, 176],
#         [174, 155, 176],
#         [174, 155, 176],
#         ...,
#         [177, 160, 181],
#         [177, 160, 181],
#         [176, 159, 180]],
#
#        [[174, 155, 176],
#         [174, 155, 176],
#         [174, 155, 176],
#         ...,
#         [177, 160, 181],
#         [177, 160, 181],
#         [176, 159, 180]],
#
#        [[174, 155, 176],
#         [174, 155, 176],
#         [174, 155, 176],
#         ...,
#         [177, 160, 181],
#         [177, 160, 181],
#         [176, 159, 180]],
#
#        ...,
#
#        [[183, 164, 189],
#         [183, 164, 189],
#         [184, 165, 190],
#         ...,
#         [193, 177, 195],
#         [193, 177, 195],
#         [191, 175, 193]],
#
#        [[183, 164, 189],
#         [183, 164, 189],
#         [184, 165, 190],
#         ...,
#         [192, 176, 194],
#         [193, 177, 195],
#         [191, 175, 193]],
#
#        [[183, 164, 189],
#         [183, 164, 189],
#         [183, 164, 189],
#         ...,
#         [192, 176, 194],
#         [192, 176, 194],
#         [191, 175, 193]]], dtype=uint8)

# %%
# displaying image
cv2.imshow("Sundar-Pichai", image)
cv2.waitKey(0)
plt.imshow(image)

# %%
# converting image to grayscale image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("New Cat", gray_image)
cv2.waitKey(0)
plt.imshow(gray_image)
gray_image
# Out:
# array([[163, 163, 163, ..., 168, 168, 167],
#        [163, 163, 163, ..., 168, 168, 167],
#        [163, 163, 163, ..., 168, 168, 167],
#        ...,
#        [174, 174, 175, ..., 184, 184, 182],
#        [174, 174, 175, ..., 183, 184, 182],
#        [174, 174, 174, ..., 183, 183, 182]], dtype=uint8)

# %%
# inverting grayscale image
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
plt.imshow(inverted_image)
inverted_image
# Out:
# array([[92, 92, 92, ..., 87, 87, 88],
#        [92, 92, 92, ..., 87, 87, 88],
#        [92, 92, 92, ..., 87, 87, 88],
#        ...,
#        [81, 81, 80, ..., 71, 71, 73],
#        [81, 81, 80, ..., 72, 71, 73],
#        [81, 81, 81, ..., 72, 72, 73]], dtype=uint8)

# %%
# blurring image using Gaussian function in OpenCV
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)
blurred
# Out:
# array([[91, 91, 91, ..., 86, 86, 86],
#        [91, 91, 91, ..., 86, 86, 86],
#        [91, 91, 91, ..., 86, 86, 86],
#        ...,
#        [79, 79, 79, ..., 71, 72, 72],
#        [80, 79, 79, ..., 72, 72, 72],
#        [80, 80, 79, ..., 72, 72, 72]], dtype=uint8)

# %%
# inverting the blurred image 
# displaying final sketch
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
plt.imshow(pencil_sketch)
pencil_sketch
# Out:
# array([[254, 254, 254, ..., 254, 254, 253],
#        [254, 254, 254, ..., 254, 254, 253],
#        [254, 254, 254, ..., 254, 254, 253],
#        ...,
#        [253, 253, 255, ..., 255, 255, 255],
#        [255, 253, 255, ..., 255, 255, 255],
#        [255, 255, 253, ..., 255, 255, 255]], dtype=uint8)

# %%
# display original image alongside pencil sketch
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ThankYou
